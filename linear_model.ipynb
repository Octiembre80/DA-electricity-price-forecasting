# %%
import pandas as pd
import numpy as np
import datetime as dt
from keras.models import load_model
from sklearn.externals import joblib
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Lasso, LassoLars, LinearRegression, ElasticNet, Ridge, PassiveAggressiveRegressor, \
SGDRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor, BaggingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV 
# %matplotlib inline

# %%
price_data = pd.read_csv('./raw_data/EPEX_spot_DA_auction_hour_prices_20070720-20170831.csv', parse_dates=True,
                        index_col=0)

# %%
actual = pd.read_csv('./processed_data/20150101-20170830-gen_per_prod_type.csv', parse_dates=True, index_col=0)
forecast = pd.read_csv('./processed_data/20150101-20170830-forecast_load_renewable_gen.csv', parse_dates=True, index_col=0)

# %%
forecast.drop('sum_forecast', axis=1, inplace=True)

# %%
timeseries_bottleneck = pd.read_csv('./bottleneck_features/bnf_timeseries.csv', parse_dates=True, index_col=0)

# %%
solar_bottleneck = pd.read_csv('./bottleneck_features/bnf_solar.csv', parse_dates=True, index_col=0)
wind_bottleneck = pd.read_csv('./bottleneck_features/bnf_wind.csv', parse_dates=True, index_col=0)

# %%
actual = actual.resample('1H').mean()
forecast = forecast.resample('1H').mean()

# %%
features = pd.concat([actual, forecast, timeseries_bottleneck, solar_bottleneck, wind_bottleneck], axis=1)
features.dropna(inplace=True)

# %%
index = features.index.intersection(price_data.index)

# %%
features = features.loc[index]
labels = price_data.loc[index]

# %%
features.columns
# Out:
# Index(['biomass', 'brown_coal', 'hard_coal', 'wind_offshore', 'pumped_hydro',
#        'solar', 'river_hydro', 'wind_onshore', 'nuclear', 'other',
#        'load_forecast', 'load_true', 'solar_forecast', 'offshore_forecast',
#        'onshore_forecast', 'timeseries_pred', 'solar_bottleneck',
#        'wind_bottleneck'],
#       dtype='object')

# %%
features.head()
# Out:
#                      biomass  brown_coal  hard_coal  wind_offshore  \
# 2015-01-01 01:00:00  4261.00    15364.75    1929.75         516.25
# 2015-01-01 02:00:00  4295.50    14852.75    1824.00         514.00
# 2015-01-01 03:00:00  4313.75    14111.00    1959.00         517.75
# 2015-01-01 04:00:00  4308.50    14149.00    2012.25         519.75
# 2015-01-01 05:00:00  4304.00    13509.50    1753.50         520.00
#
#                      pumped_hydro  solar  river_hydro  wind_onshore   nuclear  \
# 2015-01-01 01:00:00        409.50    0.0      2617.00        8367.5  11086.25
# 2015-01-01 02:00:00        632.75    0.0      2578.75        8604.0  11026.25
# 2015-01-01 03:00:00        558.25    0.0      2545.25        8617.0  11027.75
# 2015-01-01 04:00:00        602.75    0.0      2557.75        8707.5  10962.25
# 2015-01-01 05:00:00        629.25    0.0      2554.75        8775.5  10696.00
#
#                        other  load_forecast  load_true  solar_forecast  \
# 2015-01-01 01:00:00  4743.50       46952.50   47032.25             0.0
# 2015-01-01 02:00:00  4836.50       45751.50   45619.00             0.0
# 2015-01-01 03:00:00  4840.25       45306.25   44253.75             0.0
# 2015-01-01 04:00:00  4820.75       45423.00   43765.50             0.0
# 2015-01-01 05:00:00  4958.00       45701.50   43589.50             0.0
#
#                      offshore_forecast  onshore_forecast  timeseries_pred  \
# 2015-01-01 01:00:00             598.25           8161.75        16.366163
# 2015-01-01 02:00:00             599.50           8324.75        13.697455
# 2015-01-01 03:00:00             603.75           8440.25        10.958999
# 2015-01-01 04:00:00             605.25           8621.25        10.259408
# 2015-01-01 05:00:00             611.25           8825.75        11.003360
#
#                      solar_bottleneck  wind_bottleneck
# 2015-01-01 01:00:00               0.0     12577.362305
# 2015-01-01 02:00:00               0.0     11986.717773
# 2015-01-01 03:00:00               0.0     12911.827148
# 2015-01-01 04:00:00               0.0     12743.263672
# 2015-01-01 05:00:00               0.0     13013.442383

# %%
labels.head()
# Out:
#                      DA_price
# 2015-01-01 01:00:00     18.29
# 2015-01-01 02:00:00     16.04
# 2015-01-01 03:00:00     14.60
# 2015-01-01 04:00:00     14.95
# 2015-01-01 05:00:00     14.50

# %%
def apply_predictor(predictor, features, labels):
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)
    predictor.fit(X_train, y_train)
    pred = predictor.predict(X_test)
    
    mae = mean_absolute_error(y_test, pred)
    
    return mae

# %%
cols1 = ['biomass', 'brown_coal', 'hard_coal', 'wind_offshore', 'pumped_hydro',
       'solar', 'river_hydro', 'wind_onshore', 'nuclear', 'other', 'load_true']

cols2 = ['biomass', 'brown_coal', 'hard_coal', 'wind_offshore', 'pumped_hydro',
       'solar', 'river_hydro', 'wind_onshore', 'nuclear', 'other', 'load_true',
       'timeseries_pred']

cols3 = ['biomass', 'brown_coal', 'hard_coal', 'pumped_hydro', 'river_hydro',
        'nuclear', 'other', 'load_forecast', 'solar_forecast', 'offshore_forecast',
        'onshore_forecast']

cols4 = ['biomass', 'brown_coal', 'hard_coal', 'pumped_hydro', 'river_hydro',
        'nuclear', 'other', 'load_forecast', 'solar_forecast', 'offshore_forecast',
        'onshore_forecast', 'timeseries_pred']

cols5 = ['wind_offshore', 'solar', 'wind_onshore', 'load_forecast', 'timeseries_pred']

cols6 = ['load_forecast', 'solar_forecast', 'offshore_forecast', 'onshore_forecast',
        'timeseries_pred']

cols7 = ['load_true', 'solar_forecast', 'offshore_forecast', 'onshore_forecast',
        'timeseries_pred']

cols8 = ['load_forecast', 'solar_bottleneck', 'wind_bottleneck', 'timeseries_pred']

# %%
input_variations = [cols1, cols2, cols3, cols4, cols5, cols6, cols7, cols8]

# %%
for curr_feat in input_variations:
    
    mae = apply_predictor(LinearRegression(), features[curr_feat], labels)
    print('MAE: ', mae)
# Out:
# MAE:  3.58887406018
# MAE:  3.38890336459
# MAE:  3.43930478581
# MAE:  3.27488568743
# MAE:  3.67634697445
# MAE:  3.62665276734
# MAE:  3.56286427771
# MAE:  3.7734588474

# %%
for curr_feat in input_variations:
    
    mae = apply_predictor(GradientBoostingRegressor(), features[curr_feat], labels)
    print('MAE: ', mae)
# Out:
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#
ning_rate=0.05, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.05, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000, total= 1.5min
# [CV] learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100, total=   0.3s
# [CV] learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100, total=   0.3s
# [CV] learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=100, total=   0.3s
# [CV] learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=1000, total=   2.9s
# [CV] learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.1, loss=ls, max_depth=3, min_samples_split=2, n_estimators=1000, total=   2.9s
# ...
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=1000, total=   4.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=1000, total=   4.6s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=1000, total=   4.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000, total=  23.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000, total=  23.1s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=2, n_estimators=5000, total=  23.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000, total=   4.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000, total=   4.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=1000, total=   4.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000, total=  22.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000, total=  22.1s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=10, n_estimators=5000, total=  22.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=100, total=   0.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000, total=   4.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000, total=   4.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=1000, total=   4.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000, total=  21.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000, total=  21.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=3, min_samples_split=20, n_estimators=5000, total=  22.2s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100, total=   0.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100, total=   0.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=100, total=   0.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000, total=   8.6s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000, total=   8.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=1000, total=   8.6s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000, total=  40.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000, total=  40.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=2, n_estimators=5000, total=  40.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   0.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   0.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   0.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000, total=   7.2s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000, total=   7.1s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=1000, total=   7.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000, total=  34.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000, total=  34.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=10, n_estimators=5000, total=  34.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=100, total=   0.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000, total=   6.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000, total=   6.6s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=1000, total=   6.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000, total=  33.1s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000, total=  32.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=5, min_samples_split=20, n_estimators=5000, total=  33.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100, total=   4.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100, total=   4.2s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=100, total=   4.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000, total=  24.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000, total=  24.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=1000, total=  24.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000, total=  31.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000, total=  31.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=2, n_estimators=5000, total=  31.5s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100, total=   2.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100, total=   2.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=100, total=   2.3s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000, total=  17.0s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000, total=  16.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=1000, total=  16.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000, total=  31.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000, total=  32.4s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=10, n_estimators=5000, total=  31.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100, total=   1.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100, total=   1.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=100, total=   1.8s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000, total=  13.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000, total=  13.7s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=1000, total=  13.9s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000, total=  38.0s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000, total=  38.6s
# [CV] learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000
# [CV]  learning_rate=0.3, loss=huber, max_depth=10, min_samples_split=20, n_estimators=5000, total=  38.0s
# [Parallel(n_jobs=1)]: Done 729 out of 729 | elapsed: 187.8min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=7,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'loss': ('ls', 'lad', 'huber'), 'learning_rate': [0.05, 0.1, 0.3], 'n_estimators': [100, 1000, 5000], 'min_samples_split': [2, 10, 20], 'max_depth': [3, 5, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=2)

# %%
print(clf.best_params_, clf.best_score_)
# Out:
# {'learning_rate': 0.05, 'loss': 'huber', 'max_depth': 5, 'min_samples_split': 20, 'n_estimators': 100} 0.803616693861

# %%
joblib.dump(clf, './models/final_model_gridsearch.pkl')
joblib.dump(clf.best_estimator_, './models/final_model_best_estimator.pkl');

# %%
clf.best_estimator_
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.05, loss='huber', max_depth=5,
#              max_features=None, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=20,
#              min_weight_fraction_leaf=0.0, n_estimators=100,
#              presort='auto', random_state=7, subsample=1.0, verbose=0,
#              warm_start=False)

# %%
clf.best_estimator_
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.05, loss='huber', max_depth=5,
#              max_features=None, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=20,
#              min_weight_fraction_leaf=0.0, n_estimators=100,
#              presort='auto', random_state=7, subsample=1.0, verbose=0,
#              warm_start=False)

# %%
print(mean_absolute_error(labels, clf.best_estimator_.predict(features[cols8])))
# Out:
# 3.18673146368

# %%
print(mean_absolute_error(labels, clf.best_estimator_.predict(features[cols8])))
# Out:
# 3.18673146368

# %%
mae = apply_predictor(GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
         learning_rate=0.05, loss='huber', max_depth=5,
         max_features=None, max_leaf_nodes=None,
         min_impurity_decrease=0.0, min_impurity_split=None,
         min_samples_leaf=1, min_samples_split=20,
         min_weight_fraction_leaf=0.0, n_estimators=100,
         presort='auto', random_state=7, subsample=1.0, verbose=0,
         warm_start=False), features[cols4], labels)
print('MAE: ', mae)
# Out:
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MAE:  2.69307192868

# %%
X_train, X_test, y_train, y_test = train_test_split(features[cols8], labels, test_size=0.2, random_state=0)

# %%
print(mean_absolute_error(y_test, clf.best_estimator_.predict(X_test)))
# Out:
# 3.11414704769

# %%
from sklearn.model_selection import KFold

# %%
mae = apply_predictor(GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
         learning_rate=0.05, loss='huber', max_depth=5,
         max_features=None, max_leaf_nodes=None,
         min_impurity_decrease=0.0, min_impurity_split=None,
         min_samples_leaf=1, min_samples_split=20,
         min_weight_fraction_leaf=0.0, n_estimators=200,
         presort='auto', random_state=7, subsample=1.0, verbose=0,
         warm_start=False), features[cols8], labels)
print('MAE: ', mae)
# Out:
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MAE:  3.43777485824

# %%
mae = apply_predictor(GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
         learning_rate=0.05, loss='huber', max_depth=5,
         max_features=None, max_leaf_nodes=None,
         min_impurity_decrease=0.0, min_impurity_split=None,
         min_samples_leaf=1, min_samples_split=20,
         min_weight_fraction_leaf=0.0, n_estimators=500,
         presort='auto', random_state=7, subsample=1.0, verbose=0,
         warm_start=False), features[cols6], labels)
print('MAE: ', mae)
# Out:
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MAE:  3.18377165944

# %%
parameters = {'loss':['huber'], 'learning_rate':[0.05], 'n_estimators':[100, 200],
              'min_samples_split':[10], 'max_depth':[5]}
predictor = GradientBoostingRegressor(random_state=7)
clf2 = GridSearchCV(predictor, parameters, verbose=2)
clf2.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   1.0s
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=100, total=   0.9s
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200, total=   1.6s
# [CV] learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV]  learning_rate=0.05, loss=huber, max_depth=5, min_samples_split=10, n_estimators=200, total=   2.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.3s finished
# /home/fritz/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=7,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'loss': ['huber'], 'learning_rate': [0.05], 'n_estimators': [100, 200], 'min_samples_split': [10], 'max_depth': [5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=2)

# %%
clf2.best_params_
# Out:
# {'learning_rate': 0.05,
#  'loss': 'huber',
#  'max_depth': 5,
#  'min_samples_split': 10,
#  'n_estimators': 200}

# %%
print(mean_absolute_error(y_test, clf2.best_estimator_.predict(X_test)))
# Out:
# 3.43853717343

# %% [markdown]
# ### Simple Regression Model on important features

# %% [markdown]
# ### Benchmark from the timeseries model

# %%
bottleneck_timeseries = pd.read_csv('./bottleneck_features/bnf_timeseries.csv', index_col=0, parse_dates=True)
bottleneck_timeseries = bottleneck_timeseries.join(price_data, how='inner')

# %%
print(mean_absolute_error(bottleneck_timeseries.timeseries_pred, bottleneck_timeseries.DA_price))
# Out:
# 5.5289360522

# %% [markdown]
# ### Benchmark regression with perfect information

# %%
regr = LinearRegression()

regr.fit(actual.drop('DA_price', axis=1).as_matrix(), actual['DA_price'].as_matrix())

pred = regr.predict(actual.drop('DA_price', axis=1).as_matrix())

print(mean_absolute_error(actual['DA_price'].as_matrix(), pred))
# Out:
# 3.85435578932

# %%
regr = LinearRegression()

regr.fit(actual.drop('DA_price', axis=1).as_matrix(), actual['DA_price'].as_matrix())

pred = regr.predict(actual.drop('DA_price', axis=1).as_matrix())

print(mean_absolute_error(actual['DA_price'].as_matrix(), pred))
# Out:
# 4.56425788451

# %% [markdown]
# ### Using forecast inputs

# %%
regr = LinearRegression()

regr.fit(forecast.drop('DA_price', axis=1).as_matrix(), forecast['DA_price'].as_matrix())

pred = regr.predict(forecast.drop('DA_price', axis=1).as_matrix())

print(mean_absolute_error(forecast['DA_price'].as_matrix(), pred))
# Out:
# 4.99793768595

# %% [markdown]
# ### Using 'predictable' inputs

# %%
features_train = train[['load_true', 'solar','wind_offshore', 'wind_onshore',
                       'bottleneck_features']]
labels_train = train[['DA_price']]
features_test = test[['load_true', 'solar','wind_offshore', 'wind_onshore',
                       'bottleneck_features']]

# %%
regr = LinearRegression()

regr.fit(features_train.as_matrix(), labels_train.as_matrix())

pred = regr.predict(features_test)

print(mean_absolute_error(test.DA_price, pred))
# Out:
# 4.98114110312

# %%
features_train = train_sub[['load_forecast', 'solar_forecast','offshore_forecast', 'onshore_forecast',
                       'bottleneck_features']]
labels_train = train_sub[['DA_price']]
features_test = test_sub[['load_forecast', 'solar_forecast','offshore_forecast', 'onshore_forecast',
                       'bottleneck_features']]

# %%
regr = LinearRegression()

regr.fit(features_train.as_matrix(), labels_train.as_matrix())

pred = regr.predict(features_test)

print(mean_absolute_error(test_sub.DA_price, pred))
# Out:
# 4.72861605
