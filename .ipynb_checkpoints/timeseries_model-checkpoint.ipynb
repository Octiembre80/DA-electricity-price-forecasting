# %% [markdown]
# # 1. Timeseries Data Preprocessing: Day-Ahead prices

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
da_raw = pd.read_csv('./raw_data/EPEX_spot_DA_auction_hour_prices_20070720-20170831.csv',
                     index_col=0, parse_dates=True)
da_raw.head(n=5)
# Out:
#                      DA_price
# 2007-07-20 00:00:00     25.69
# 2007-07-20 01:00:00     26.45
# 2007-07-20 02:00:00     24.33
# 2007-07-20 03:00:00     23.57
# 2007-07-20 04:00:00     18.96

# %%
da_raw.describe().T
# Out:
#             count       mean        std     min   25%    50%    75%    max
# DA_price  88704.0  41.295654  21.352333 -500.02  29.0  38.64  50.97  821.9

# %%
# check if their are any gaps within the data
any(da_raw.dropna().index.to_series().diff() > pd.Timedelta('01:00:00'))
# Out:
# False

# %%
ax = da_raw.plot(figsize=(15, 6))
ax.set_ylabel('Day-Ahead market clearing prices in $EUR/MWh$')

# %% [markdown]
# __Analysis__
#
# We can see that there are extreme price peaks in the late 2007 and extreme price lows in late 2009. These price peaks are most likely due to market flaws in the early days of Day-Ahead trading. We can see that the price range gets substantially smaller in the later years. These extreme prices should be removed to avoid problems when scaling the data to a range between 0 and 1 for input into a regression algorithm.

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 10))
da_raw.groupby(da_raw.index.month).mean().plot(ax=ax1, drawstyle='steps')
da_raw.groupby(da_raw.index.dayofweek).mean().plot(ax=ax2, drawstyle='steps')
da_raw.groupby(da_raw.index.hour).mean().plot(ax=ax3, drawstyle='steps')

# %% [markdown]
# __Analysis__
#
# tbd

# %%
# keep raw data of the test set for model evaluation
test_raw = da_raw['2017']

# %%
da_prep = pd.DataFrame(index=da_raw.index)

# %%
# calculate quantiles and inter-quantile range of the data
q75 = da_raw['DA_price'].quantile(.75)
q25 = da_raw['DA_price'].quantile(.25)
IQR = q75 - q25

# values larger (smaller) than q75 (q25) plus 'tol' times IQR get replaces by that value
tol = 3
da_prep['DA_price'] = da_raw['DA_price'].apply(lambda x: q75 + tol * IQR if (x > q75 + tol * IQR) else x)
da_prep['DA_price'] = da_prep['DA_price'].apply(lambda x: q25 - tol * IQR if (x < q75 - tol * IQR) else x)

# %%
ax = da_prep.plot(figsize=(15, 6))
ax.set_ylabel('Day-Ahead market clearing prices in $EUR/MWh$')

# %% [markdown]
# __Analysis__
#
# The range of the prices now looks much more appropriate to be scaled to 0-1 values. When scaling, the data will now be much more spread out instead of concentrating around some median value, as it would have been the case when the outliers would not have been removed.

# %%
da_prep.hist(bins=200, figsize=(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f44257194e0>]], dtype=object)

# %%
# scale data to range between 0 and 1
da_scaler = MinMaxScaler()
da_prep['DA_price'] = da_scaler.fit_transform(da_prep['DA_price'].values.reshape(-1, 1))

# %%
# include time lags of timeseries data for 1 week = 7 * 24h = 168h
lags = 168
for l in range(1, lags+1):
    da_prep['l_{}'.format(l)] = da_prep['DA_price'].shift(l)

# %%
# drop missing data entries that result from the lagging step (no lagged data available for first 168 days of year)
da_prep.dropna(inplace=True)
da_prep.head(n=5)
# Out:
#                      DA_price       l_1       l_2       l_3       l_4  \
# 2007-07-27 00:00:00  0.388972  0.390402  0.435139  0.409454  0.421354
# 2007-07-27 01:00:00  0.369920  0.388972  0.390402  0.435139  0.409454
# 2007-07-27 02:00:00  0.343325  0.369920  0.388972  0.390402  0.435139
# 2007-07-27 03:00:00  0.330451  0.343325  0.369920  0.388972  0.390402
# 2007-07-27 04:00:00  0.300800  0.330451  0.343325  0.369920  0.388972
#
#                           l_5       l_6       l_7       l_8       l_9  \
# 2007-07-27 00:00:00  0.429027  0.435529  0.432083  0.454516  0.455231
# 2007-07-27 01:00:00  0.421354  0.429027  0.435529  0.432083  0.454516
# 2007-07-27 02:00:00  0.409454  0.421354  0.429027  0.435529  0.432083
# 2007-07-27 03:00:00  0.435139  0.409454  0.421354  0.429027  0.435529
# 2007-07-27 04:00:00  0.390402  0.435139  0.409454  0.421354  0.429027
#
#                        ...        l_159     l_160     l_161     l_162  \
# 2007-07-27 00:00:00    ...     0.591716  0.558164  0.468236  0.425450
# 2007-07-27 01:00:00    ...     0.858053  0.591716  0.558164  0.468236
# 2007-07-27 02:00:00    ...     0.880031  0.858053  0.591716  0.558164
# 2007-07-27 03:00:00    ...     0.760518  0.880031  0.858053  0.591716
# 2007-07-27 04:00:00    ...     0.578711  0.760518  0.880031  0.858053
#
#                         l_163     l_164     l_165     l_166     l_167  \
# 2007-07-27 00:00:00  0.406984  0.363288  0.393264  0.398205  0.411990
# 2007-07-27 01:00:00  0.425450  0.406984  0.363288  0.393264  0.398205
# 2007-07-27 02:00:00  0.468236  0.425450  0.406984  0.363288  0.393264
# 2007-07-27 03:00:00  0.558164  0.468236  0.425450  0.406984  0.363288
# 2007-07-27 04:00:00  0.591716  0.558164  0.468236  0.425450  0.406984
#
#                         l_168
# 2007-07-27 00:00:00  0.407049
# 2007-07-27 01:00:00  0.411990
# 2007-07-27 02:00:00  0.398205
# 2007-07-27 03:00:00  0.393264
# 2007-07-27 04:00:00  0.363288
#
# [5 rows x 169 columns]

# %%
# create feature and label dataframes
prelim_features = da_prep.drop('DA_price', axis=1)
prelim_labels = pd.DataFrame(da_prep['DA_price'])

# %%
# format labels to 24 hour output range
for i in range(0, 24):
    prelim_labels['t_{}'.format(i)] = prelim_labels['DA_price'].shift(-i)
prelim_labels.drop('DA_price', axis=1, inplace=True)

# %%
# apply one-day discretization to the data
labels = prelim_labels[prelim_labels.index.hour == 0]
features = prelim_features[prelim_features.index.hour == 0]

# %%
features_train = features[:'2016']
features_test = features['2017':]
labels_train = labels[:'2016']

# %%
samples_train = len(features_train)
samples_test = len(features_test)
timesteps = 168

# %%
# convert pandas data frames to numpy ndarrays
features_train = features_train.as_matrix().reshape(samples_train, timesteps, 1)
features_test = features_test.as_matrix().reshape(samples_test, timesteps, 1)
labels_train = labels_train.as_matrix()

# %%
# check for correct data shape
features_train.shape, labels_train.shape
# Out:
# ((3446, 168, 1), (3446, 24))

# %% [markdown]
# # 2. Timeseries Model: Experimenting with structures

# %%
from keras.models import Model, load_model
from keras.layers import Input, Add
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Conv1D
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
# Out:
# Using TensorFlow backend.

# %%
# split into training and validation data
X_train, X_valid, y_train, y_valid = train_test_split(features_train, labels_train, test_size=0.2, random_state=7)

# %% [markdown]
# ## Benchmark models

# %% [markdown]
# ### Naive benchmark models

# %%
benchmark_results = pd.DataFrame(index=test_raw.index)

# %%
benchmark_results['last_day'] = da_raw.shift(24)['2017']

# %%
benchmark_results['last_week'] = da_raw.shift(24*7)['2017']

# %%
benchmark_results['2_week_average'] = pd.concat([da_raw.shift(24 * w) for w in range(1, 3)], axis=1).mean(axis=1)['2017']

# %%
benchmark_results['4_week_average'] = pd.concat([da_raw.shift(24 * w) for w in range(1, 5)], axis=1).mean(axis=1)['2017']

# %%
for col in benchmark_results.columns:
    pred = benchmark_results[col].as_matrix()
    true = test_raw.DA_price.as_matrix()
    print('MAE of {} benchmark model: '.format(col), mean_absolute_error(y_pred=pred, y_true=true))
# Out:
# MAE of last_day benchmark model:  8.5257441701
# MAE of last_week benchmark model:  9.13819101509
# MAE of 2_week_average benchmark model:  8.97544495885
# MAE of 4_week_average benchmark model:  9.17504458162

# %% [markdown]
# ### Simple linear models

# %%
lin_input_layer = Input(shape=(X_train.shape[1],))
x = Dense(24)(lin_input_layer)

model = Model(inputs=[lin_input_layer], outputs=[x])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 168)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                4056
# =================================================================
# Total params: 4,056
# Trainable params: 4,056
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_only.hdf5', save_best_only=True)
hist = model.fit(X_train.reshape(X_train.shape[0], X_train.shape[1]), y_train,
                 validation_data=(X_valid.reshape(X_valid.shape[0], X_valid.shape[1]), y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_only.hdf5')
pred = best.predict(features_test.reshape(features_test.shape[0], features_test.shape[1]))
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))
index = da_prep[da_prep.index.year == 2017].index
results = pd.DataFrame({'pred':pred.flatten(), 'true':test_raw.DA_price}, index=index)

# %%
print('MAE : ', mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# MAE :  6.0996195546

# %%
lin_input_layer = Input(shape=(X_train.shape[1],))
x = Dense(64)(lin_input_layer)
x = Dense(24)(x)

model = Model(inputs=[lin_input_layer], outputs=[x])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 168)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                10816
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                1560
# =================================================================
# Total params: 12,376
# Trainable params: 12,376
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_only.hdf5', save_best_only=True)
hist = model.fit(X_train.reshape(X_train.shape[0], X_train.shape[1]), y_train,
                 validation_data=(X_valid.reshape(X_valid.shape[0], X_valid.shape[1]), y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_only.hdf5')
pred = best.predict(features_test.reshape(features_test.shape[0], features_test.shape[1]))
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))
index = da_prep[da_prep.index.year == 2017].index
results = pd.DataFrame({'pred':pred.flatten(), 'true':test_raw.DA_price}, index=index)

# %%
print('MAE : ', mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# MAE :  5.8387074386

# %% [markdown]
# ## First experimental architecture

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(input_layer)
x = LSTM(32, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model = Model(inputs=[input_layer], outputs=[output_layer])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 168, 1)            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 7, 64)             1600
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_21 (Dense)             (None, 24)                792
# =================================================================
# Total params: 14,808
# Trainable params: 14,808
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
checkpoint = ModelCheckpoint('./models/timeseries_conv_LSTM_first_test.hdf5', save_best_only=True)
hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[checkpoint],
                verbose=1, batch_size=50, epochs=200)
# Out:
# Train on 2756 samples, validate on 690 samples
# Epoch 1/200
# 2756/2756 [==============================] - 2s - loss: 0.1684 - val_loss: 0.0493
# Epoch 2/200
# 2756/2756 [==============================] - 0s - loss: 0.0180 - val_loss: 0.0072
# Epoch 3/200
# 2756/2756 [==============================] - 0s - loss: 0.0068 - val_loss: 0.0069
# Epoch 4/200
# 2756/2756 [==============================] - 0s - loss: 0.0066 - val_loss: 0.0067
# Epoch 5/200
# 2756/2756 [==============================] - 0s - loss: 0.0065 - val_loss: 0.0066
# Epoch 6/200
# 2756/2756 [==============================] - 0s - loss: 0.0065 - val_loss: 0.0065
# Epoch 7/200
# 2756/2756 [==============================] - 0s - loss: 0.0064 - val_loss: 0.0064
# Epoch 8/200
# 2756/2756 [==============================] - 0s - loss: 0.0063 - val_loss: 0.0064
# Epoch 9/200
# 2756/2756 [==============================] - 0s - loss: 0.0062 - val_loss: 0.0063
# Epoch 10/200
# 2756/2756 [==============================] - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 11/200
# 2756/2756 [==============================] - 0s - loss: 0.0061 - val_loss: 0.0061
# Epoch 12/200
# 2756/2756 [==============================] - 0s - loss: 0.0060 - val_loss: 0.0066
# Epoch 13/200
# 2756/2756 [==============================] - 0s - loss: 0.0060 - val_loss: 0.0061
# Epoch 14/200
# 2756/2756 [==============================] - 0s - loss: 0.0060 - val_loss: 0.0072
# Epoch 15/200
# 2756/2756 [==============================] - 0s - loss: 0.0059 - val_loss: 0.0062
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

# %%
index = da_prep[da_prep.index.year == 2017].index

results = pd.DataFrame({'pred':pred.flatten(), 'true':test_raw.DA_price}, index=index)

# %%
print(mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# 5.90744472015

# %%
results.plot(figsize=(12, 6))

# %% [markdown]
# ## Trying different architectures

# %%
archs = []

# %% [markdown]
# ##### Smaller Convolutional layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(32, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(32, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_a = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_a)

# %% [markdown]
# ##### Smaller Recurrent layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(16, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_b = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_b)

# %% [markdown]
# ##### Smaller Convolutional and Recurrent layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(32, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(16, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_c = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_c)

# %% [markdown]
# ##### Bigger Convolutional layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(128, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(32, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_d = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_d)

# %% [markdown]
# ##### Bigger Recurrent layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(64, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_e = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_e)

# %% [markdown]
# ##### Bigger Convolutional and Recurrent Layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(128, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(64, recurrent_activation='relu')(x)
output_layer = Dense(24)(x)
model_f = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_f)

# %% [markdown]
# ##### With additional Dense Layer

# %%
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(input_layer)
# x = LSTM(32, return_sequences=True, recurrent_activation='relu')(x)
x = LSTM(32, recurrent_activation='relu')(x)
x = Dense(32)(x)
output_layer = Dense(24)(x)
model_g = Model(inputs=[input_layer], outputs=[output_layer])
archs.append(model_g)

# %%
for i, model in enumerate(archs):
    model.compile(loss='mse', optimizer='adam')
    checkpoint = ModelCheckpoint('./models/timeseries_architecture_testing_model_{}.hdf5'.format(i), save_best_only=True)
    hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), callbacks=[checkpoint], 
                     verbose=0, batch_size=50, epochs=200)
    best = load_model('./models/timeseries_architecture_testing_model_{}.hdf5'.format(i))
    pred = best.predict(features_test)
    pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))
    index = da_prep[da_prep.index.year == 2017].index
    results = pd.DataFrame({'pred':pred.flatten(), 'true':test_raw.DA_price}, index=index)
    print('MAE of model {}: '.format(i), mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# MAE of model 0:  5.762188079
# MAE of model 1:  6.15960305753
# MAE of model 2:  5.75341784547
# MAE of model 3:  5.93660107021
# MAE of model 4:  5.95871355456
# MAE of model 5:  5.78408111743
# MAE of model 6:  5.9574115549

# %% [markdown]
# #### Adding a linear bypass

# %%
conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
lin_input_layer = Input(shape=(X_train.shape[1],))

x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(conv_input_layer)
x = LSTM(32, recurrent_activation='relu')(x)
x = Dense(24)(x)

y = Dense(64)(lin_input_layer)
y = Dense(24)(y)

add = Add()([x, y])

model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_19 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_17 (Conv1D)               (None, 7, 64)         1600        input_19[0][0]
# ____________________________________________________________________________________________________
# input_20 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_17 (LSTM)                   (None, 32)            12416       conv1d_17[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 64)            10816       input_20[0][0]
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 24)            792         lstm_17[0][0]
# ____________________________________________________________________________________________________
# dense_24 (Dense)                 (None, 24)            1560        dense_23[0][0]
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 24)            0           dense_22[0][0]
#                                                                    dense_24[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_bypass.hdf5', save_best_only=True)
hist = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=1, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_bypass.hdf5')
pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))
index = da_prep[da_prep.index.year == 2017].index
results = pd.DataFrame({'pred':pred.flatten(), 'true':test_raw.DA_price}, index=index)
# Out:
# Train on 2756 samples, validate on 690 samples
# Epoch 1/200
# 2756/2756 [==============================] - 1s - loss: 0.0812 - val_loss: 0.0169
# Epoch 2/200
# 2756/2756 [==============================] - 0s - loss: 0.0146 - val_loss: 0.0131
# Epoch 3/200
# 2756/2756 [==============================] - 0s - loss: 0.0116 - val_loss: 0.0106
# Epoch 4/200
# 2756/2756 [==============================] - 0s - loss: 0.0098 - val_loss: 0.0092
# Epoch 5/200
# 2756/2756 [==============================] - 0s - loss: 0.0086 - val_loss: 0.0083
# Epoch 6/200
# 2756/2756 [==============================] - 0s - loss: 0.0077 - val_loss: 0.0075
# Epoch 7/200
# 2756/2756 [==============================] - 0s - loss: 0.0071 - val_loss: 0.0070
# Epoch 8/200
# 2756/2756 [==============================] - 0s - loss: 0.0067 - val_loss: 0.0067
# Epoch 9/200
# 2756/2756 [==============================] - 0s - loss: 0.0064 - val_loss: 0.0064
# Epoch 10/200
# 2756/2756 [==============================] - 0s - loss: 0.0061 - val_loss: 0.0064
# Epoch 11/200
# 2756/2756 [==============================] - 0s - loss: 0.0058 - val_loss: 0.0065
# Epoch 12/200
# 2756/2756 [==============================] - 0s - loss: 0.0056 - val_loss: 0.0058
# Epoch 13/200
# 2756/2756 [==============================] - 0s - loss: 0.0054 - val_loss: 0.0057
# Epoch 14/200
# 2756/2756 [==============================] - 0s - loss: 0.0053 - val_loss: 0.0053
# Epoch 15/200
# 2756/2756 [==============================] - 0s - loss: 0.0052 - val_loss: 0.0053
# Epoch 16/200
# 2756/2756 [==============================] - 0s - loss: 0.0050 - val_loss: 0.0050
# Epoch 17/200
# 2756/2756 [==============================] - 0s - loss: 0.0048 - val_loss: 0.0051
# Epoch 18/200
# 2756/2756 [==============================] - 0s - loss: 0.0049 - val_loss: 0.0049
# Epoch 19/200
# 2756/2756 [==============================] - 0s - loss: 0.0046 - val_loss: 0.0049
# Epoch 20/200
# 2756/2756 [==============================] - 0s - loss: 0.0046 - val_loss: 0.0048
# Epoch 21/200
# 2756/2756 [==============================] - 0s - loss: 0.0046 - val_loss: 0.0046
# Epoch 22/200
# 2756/2756 [==============================] - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 23/200
# 2756/2756 [==============================] - 0s - loss: 0.0044 - val_loss: 0.0046
# Epoch 24/200
# 2756/2756 [==============================] - 0s - loss: 0.0044 - val_loss: 0.0047
# Epoch 25/200
# 2756/2756 [==============================] - 0s - loss: 0.0044 - val_loss: 0.0047
# Epoch 26/200
# 2756/2756 [==============================] - 0s - loss: 0.0044 - val_loss: 0.0049
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0033
# Epoch 183/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0031
# Epoch 184/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0031
# Epoch 185/200
# 2756/2756 [==============================] - 0s - loss: 0.0031 - val_loss: 0.0035
# Epoch 186/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 187/200
# 2756/2756 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0033
# Epoch 188/200
# 2756/2756 [==============================] - 0s - loss: 0.0031 - val_loss: 0.0030
# Epoch 189/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 190/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 191/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0033
# Epoch 192/200
# 2756/2756 [==============================] - 0s - loss: 0.0033 - val_loss: 0.0031
# Epoch 193/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0033
# Epoch 194/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 195/200
# 2756/2756 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0031
# Epoch 196/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 197/200
# 2756/2756 [==============================] - 0s - loss: 0.0030 - val_loss: 0.0032
# Epoch 198/200
# 2756/2756 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0029
# Epoch 199/200
# 2756/2756 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0029
# Epoch 200/200
# 2756/2756 [==============================] - 0s - loss: 0.0029 - val_loss: 0.0031

# %%
print('MAE : ', mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# MAE :  5.65448441763

# %% [markdown]
# ## Finetuning the model

# %%
conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
lin_input_layer = Input(shape=(X_train.shape[1],))

x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(conv_input_layer)
x = Dropout(0.2)(x)
x = LSTM(32, recurrent_activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(24)(x)

y = Dense(64)(lin_input_layer)
y = Dropout(0.2)(y)
y = Dense(24)(y)

add = Add()([x, y])

model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_bypass_dropout.hdf5', save_best_only=True)
hist = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_bypass_dropout.hdf5')
pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

# %%
print(mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# 5.53925685797

# %%
from keras.regularizers import l1_l2

# %%
conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
lin_input_layer = Input(shape=(X_train.shape[1],))

x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(conv_input_layer)
x = Dropout(0.2)(x)
x = LSTM(32, recurrent_activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(24)(x)

y = Dense(64, kernel_regularizer=l1_l2())(lin_input_layer)
y = Dropout(0.2)(y)
y = Dense(24)(y)

add = Add()([x, y])

model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5', save_best_only=True)
hist = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5')
pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

# %%
print(mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# 6.01767128199

# %%
conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
lin_input_layer = Input(shape=(X_train.shape[1],))

x = Conv1D(64, kernel_size=24, strides=24, padding='valid')(conv_input_layer)
x = Dropout(0.2)(x)
x = LSTM(32, recurrent_activation='relu', kernel_regularizer=l1_l2())(x)
x = Dropout(0.2)(x)
x = Dense(24)(x)

y = Dense(64, kernel_regularizer=l1_l2())(lin_input_layer)
y = Dropout(0.2)(y)
y = Dense(24)(y)

add = Add()([x, y])

model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5', save_best_only=True)
hist = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5')
pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

# %%
print(mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# 8.19790622125

# %%
conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
lin_input_layer = Input(shape=(X_train.shape[1],))

x = Conv1D(64, kernel_size=24, strides=24, padding='valid', kernel_regularizer=l1_l2())(conv_input_layer)
x = Dropout(0.2)(x)
x = LSTM(32, recurrent_activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(24)(x)

y = Dense(64, kernel_regularizer=l1_l2())(lin_input_layer)
y = Dropout(0.2)(y)
y = Dense(24)(y)

add = Add()([x, y])

model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])

# %%
model.compile(loss='mse', optimizer='adam')
checkpoint = ModelCheckpoint('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5', save_best_only=True)
hist = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=50, epochs=200)

best = load_model('./models/timeseries_linear_bypass_dropout_l1-l2.hdf5')
pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

# %%
print(mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix()))
# Out:
# 8.17709985824

# %% [markdown]
# ### Hyperparameter tuning

# %% [markdown]
# sklearn GridSearchCV does not work with multi-input models, as stated in https://github.com/fchollet/keras/issues/6451

# %%
from sklearn.model_selection import ShuffleSplit, ParameterGrid
from sklearn.metrics import mean_squared_error

# %%
grid = {'optimizer': ['adam', 'rmsprop', 'adagrad'],
                  'loss': ['mse', 'mae'],
                  'batch_size': [10, 50],
                  'dropout': [0.1, 0.2],
                  'l1_l2': [0.005, 0.01, 0.02],
                  'conv_activation': ['relu', 'tanh'],
                  'recurrent_activation': ['relu', 'tanh']}

# %%
tot = len(ParameterGrid(grid))

# %%
parameter_grid = ParameterGrid(grid)

results = {}

for i, params in enumerate(parameter_grid):
    print('training {} out of {} parameter configurations'.format(i, tot))
    param_results = {}
    splits = ShuffleSplit(n_splits=5, test_size=0.2, random_state=7).split(features_train, labels_train)
    
    for n, (train_indices, valid_indices) in enumerate(splits):

        X_train = features_train[train_indices]
        X_valid = features_train[valid_indices]
        y_train = labels_train[train_indices]
        y_valid = labels_train[valid_indices]
        
        conv_input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
        lin_input_layer = Input(shape=(X_train.shape[1],))

        x = Conv1D(64, kernel_size=24, strides=24, padding='valid', activation=params['conv_activation'])(conv_input_layer)
        x = Dropout(params['dropout'])(x)
        x = LSTM(32, recurrent_activation=params['recurrent_activation'])(x)
        x = Dropout(params['dropout'])(x)
        x = Dense(24)(x)

        y = Dense(64, kernel_regularizer=l1_l2(params['l1_l2']))(lin_input_layer)
        y = Dropout(params['dropout'])(y)
        y = Dense(24)(y)

        add = Add()([x, y])

        model = Model(inputs=[conv_input_layer, lin_input_layer], outputs=[add])
        model.compile(loss=params['loss'], optimizer=params['optimizer'])

        checkpoint = ModelCheckpoint('./models/timeseries_grid_search.hdf5', save_best_only=True)
        _ = model.fit([X_train, X_train.reshape(X_train.shape[0], X_train.shape[1])], y_train,
                 validation_data=([X_valid, X_valid.reshape(X_valid.shape[0], X_valid.shape[1])], y_valid),
                 callbacks=[checkpoint], 
                 verbose=0, batch_size=params['batch_size'], epochs=200)

        best = load_model('./models/timeseries_grid_search.hdf5')
        pred = best.predict([features_test, features_test.reshape(features_test.shape[0], features_test.shape[1])])
        pred = da_scaler.inverse_transform(pred.flatten().reshape(-1, 1))

        mse = mean_squared_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix())
        mae = mean_absolute_error(y_pred=pred, y_true=test_raw.DA_price.as_matrix())

        param_results['split{}'.format(n)] = {'mae':mae, 'mse':mse}

    mae_avg = np.mean([param_results[key]['mae'] for key in param_results.keys()])
    mse_avg = np.mean([param_results[key]['mse'] for key in param_results.keys()])

    results[str(params)] = {'splits':param_results, 'mae_avg':mae_avg, 'mse_avg':mse_avg}
    
    with open('./timeseries_gridsearch_results.json', 'w') as fp:
        json.dump(results, fp)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_45 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_16 (Conv1D)               (None, 7, 64)         1600        input_45[0][0]
# ____________________________________________________________________________________________________
# dropout_31 (Dropout)             (None, 7, 64)         0           conv1d_16[0][0]
# ____________________________________________________________________________________________________
# input_46 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_16 (LSTM)                   (None, 32)            12416       dropout_31[0][0]
# ____________________________________________________________________________________________________
# dense_57 (Dense)                 (None, 64)            10816       input_46[0][0]
# ____________________________________________________________________________________________________
# dropout_32 (Dropout)             (None, 32)            0           lstm_16[0][0]
# ____________________________________________________________________________________________________
# dropout_33 (Dropout)             (None, 64)            0           dense_57[0][0]
# ____________________________________________________________________________________________________
# dense_56 (Dense)                 (None, 24)            792         dropout_32[0][0]
# ____________________________________________________________________________________________________
# dense_58 (Dense)                 (None, 24)            1560        dropout_33[0][0]
# ____________________________________________________________________________________________________
# add_16 (Add)                     (None, 24)            0           dense_56[0][0]
#                                                                    dense_58[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_47 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_17 (Conv1D)               (None, 7, 64)         1600        input_47[0][0]
# ____________________________________________________________________________________________________
# dropout_34 (Dropout)             (None, 7, 64)         0           conv1d_17[0][0]
# ____________________________________________________________________________________________________
# input_48 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_17 (LSTM)                   (None, 32)            12416       dropout_34[0][0]
# ____________________________________________________________________________________________________
# dense_60 (Dense)                 (None, 64)            10816       input_48[0][0]
# ____________________________________________________________________________________________________
# dropout_35 (Dropout)             (None, 32)            0           lstm_17[0][0]
# ____________________________________________________________________________________________________
# dropout_36 (Dropout)             (None, 64)            0           dense_60[0][0]
# ____________________________________________________________________________________________________
# dense_59 (Dense)                 (None, 24)            792         dropout_35[0][0]
# ____________________________________________________________________________________________________
# dense_61 (Dense)                 (None, 24)            1560        dropout_36[0][0]
# ____________________________________________________________________________________________________
# add_17 (Add)                     (None, 24)            0           dense_59[0][0]
#                                                                    dense_61[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_49 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_18 (Conv1D)               (None, 7, 64)         1600        input_49[0][0]
# ____________________________________________________________________________________________________
# dropout_37 (Dropout)             (None, 7, 64)         0           conv1d_18[0][0]
# ____________________________________________________________________________________________________
# input_50 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_18 (LSTM)                   (None, 32)            12416       dropout_37[0][0]
# ____________________________________________________________________________________________________
# dense_63 (Dense)                 (None, 64)            10816       input_50[0][0]
# ____________________________________________________________________________________________________
# dropout_38 (Dropout)             (None, 32)            0           lstm_18[0][0]
# ____________________________________________________________________________________________________
# dropout_39 (Dropout)             (None, 64)            0           dense_63[0][0]
# ____________________________________________________________________________________________________
# dense_62 (Dense)                 (None, 24)            792         dropout_38[0][0]
# ____________________________________________________________________________________________________
# dense_64 (Dense)                 (None, 24)            1560        dropout_39[0][0]
# ____________________________________________________________________________________________________
# add_18 (Add)                     (None, 24)            0           dense_62[0][0]
#                                                                    dense_64[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_51 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_19 (Conv1D)               (None, 7, 64)         1600        input_51[0][0]
# ____________________________________________________________________________________________________
# dropout_40 (Dropout)             (None, 7, 64)         0           conv1d_19[0][0]
# ____________________________________________________________________________________________________
# input_52 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_19 (LSTM)                   (None, 32)            12416       dropout_40[0][0]
# ____________________________________________________________________________________________________
# dense_66 (Dense)                 (None, 64)            10816       input_52[0][0]
# ____________________________________________________________________________________________________
# dropout_41 (Dropout)             (None, 32)            0           lstm_19[0][0]
# ____________________________________________________________________________________________________
# dropout_42 (Dropout)             (None, 64)            0           dense_66[0][0]
# ____________________________________________________________________________________________________
# dense_65 (Dense)                 (None, 24)            792         dropout_41[0][0]
# ____________________________________________________________________________________________________
# dense_67 (Dense)                 (None, 24)            1560        dropout_42[0][0]
# ____________________________________________________________________________________________________
# add_19 (Add)                     (None, 24)            0           dense_65[0][0]
#                                                                    dense_67[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_53 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_20 (Conv1D)               (None, 7, 64)         1600        input_53[0][0]
# ____________________________________________________________________________________________________
# dropout_43 (Dropout)             (None, 7, 64)         0           conv1d_20[0][0]
# ____________________________________________________________________________________________________
# input_54 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_20 (LSTM)                   (None, 32)            12416       dropout_43[0][0]
# ____________________________________________________________________________________________________
# dense_69 (Dense)                 (None, 64)            10816       input_54[0][0]
# ____________________________________________________________________________________________________
# dropout_44 (Dropout)             (None, 32)            0           lstm_20[0][0]
# ____________________________________________________________________________________________________
# dropout_45 (Dropout)             (None, 64)            0           dense_69[0][0]
# ____________________________________________________________________________________________________
# dense_68 (Dense)                 (None, 24)            792         dropout_44[0][0]
# ____________________________________________________________________________________________________
# dense_70 (Dense)                 (None, 24)            1560        dropout_45[0][0]
# ____________________________________________________________________________________________________
# add_20 (Add)                     (None, 24)            0           dense_68[0][0]
#                                                                    dense_70[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_55 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_21 (Conv1D)               (None, 7, 64)         1600        input_55[0][0]
# ____________________________________________________________________________________________________
# dropout_46 (Dropout)             (None, 7, 64)         0           conv1d_21[0][0]
# ____________________________________________________________________________________________________
# input_56 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_21 (LSTM)                   (None, 32)            12416       dropout_46[0][0]
# ____________________________________________________________________________________________________
# dense_72 (Dense)                 (None, 64)            10816       input_56[0][0]
# ____________________________________________________________________________________________________
# dropout_47 (Dropout)             (None, 32)            0           lstm_21[0][0]
# ____________________________________________________________________________________________________
# dropout_48 (Dropout)             (None, 64)            0           dense_72[0][0]
# ____________________________________________________________________________________________________
# dense_71 (Dense)                 (None, 24)            792         dropout_47[0][0]
# ____________________________________________________________________________________________________
# dense_73 (Dense)                 (None, 24)            1560        dropout_48[0][0]
# ____________________________________________________________________________________________________
# add_21 (Add)                     (None, 24)            0           dense_71[0][0]
#                                                                    dense_73[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_57 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_22 (Conv1D)               (None, 7, 64)         1600        input_57[0][0]
# ____________________________________________________________________________________________________
# dropout_49 (Dropout)             (None, 7, 64)         0           conv1d_22[0][0]
# ____________________________________________________________________________________________________
# input_58 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_22 (LSTM)                   (None, 32)            12416       dropout_49[0][0]
# ____________________________________________________________________________________________________
# dense_75 (Dense)                 (None, 64)            10816       input_58[0][0]
# ____________________________________________________________________________________________________
# dropout_50 (Dropout)             (None, 32)            0           lstm_22[0][0]
# ____________________________________________________________________________________________________
# dropout_51 (Dropout)             (None, 64)            0           dense_75[0][0]
# ____________________________________________________________________________________________________
# dense_74 (Dense)                 (None, 24)            792         dropout_50[0][0]
# ____________________________________________________________________________________________________
# dense_76 (Dense)                 (None, 24)            1560        dropout_51[0][0]
# ____________________________________________________________________________________________________
# add_22 (Add)                     (None, 24)            0           dense_74[0][0]
#                                                                    dense_76[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_59 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_23 (Conv1D)               (None, 7, 64)         1600        input_59[0][0]
# ____________________________________________________________________________________________________
# dropout_52 (Dropout)             (None, 7, 64)         0           conv1d_23[0][0]
# ____________________________________________________________________________________________________
# input_60 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_23 (LSTM)                   (None, 32)            12416       dropout_52[0][0]
# ____________________________________________________________________________________________________
# dense_78 (Dense)                 (None, 64)            10816       input_60[0][0]
# ____________________________________________________________________________________________________
# dropout_53 (Dropout)             (None, 32)            0           lstm_23[0][0]
# ____________________________________________________________________________________________________
# dropout_54 (Dropout)             (None, 64)            0           dense_78[0][0]
# ____________________________________________________________________________________________________
# dense_77 (Dense)                 (None, 24)            792         dropout_53[0][0]
# ____________________________________________________________________________________________________
# dense_79 (Dense)                 (None, 24)            1560        dropout_54[0][0]
# ____________________________________________________________________________________________________
# add_23 (Add)                     (None, 24)            0           dense_77[0][0]
#                                                                    dense_79[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_61 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_24 (Conv1D)               (None, 7, 64)         1600        input_61[0][0]
# ____________________________________________________________________________________________________
# dropout_55 (Dropout)             (None, 7, 64)         0           conv1d_24[0][0]
# ____________________________________________________________________________________________________
# input_62 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_24 (LSTM)                   (None, 32)            12416       dropout_55[0][0]
# ____________________________________________________________________________________________________
# dense_81 (Dense)                 (None, 64)            10816       input_62[0][0]
# ____________________________________________________________________________________________________
# dropout_56 (Dropout)             (None, 32)            0           lstm_24[0][0]
# ____________________________________________________________________________________________________
# dropout_57 (Dropout)             (None, 64)            0           dense_81[0][0]
# ____________________________________________________________________________________________________
# dense_80 (Dense)                 (None, 24)            792         dropout_56[0][0]
# ____________________________________________________________________________________________________
# dense_82 (Dense)                 (None, 24)            1560        dropout_57[0][0]
# ____________________________________________________________________________________________________
# add_24 (Add)                     (None, 24)            0           dense_80[0][0]
#                                                                    dense_82[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_63 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_25 (Conv1D)               (None, 7, 64)         1600        input_63[0][0]
# ____________________________________________________________________________________________________
# dropout_58 (Dropout)             (None, 7, 64)         0           conv1d_25[0][0]
# ____________________________________________________________________________________________________
# input_64 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_25 (LSTM)                   (None, 32)            12416       dropout_58[0][0]
# ____________________________________________________________________________________________________
# dense_84 (Dense)                 (None, 64)            10816       input_64[0][0]
# ____________________________________________________________________________________________________
# dropout_59 (Dropout)             (None, 32)            0           lstm_25[0][0]
# ____________________________________________________________________________________________________
# dropout_60 (Dropout)             (None, 64)            0           dense_84[0][0]
# ____________________________________________________________________________________________________
# dense_83 (Dense)                 (None, 24)            792         dropout_59[0][0]
# ____________________________________________________________________________________________________
# dense_85 (Dense)                 (None, 24)            1560        dropout_60[0][0]
# ____________________________________________________________________________________________________
# add_25 (Add)                     (None, 24)            0           dense_83[0][0]
#                                                                    dense_85[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_65 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_26 (Conv1D)               (None, 7, 64)         1600        input_65[0][0]
# ____________________________________________________________________________________________________
# dropout_61 (Dropout)             (None, 7, 64)         0           conv1d_26[0][0]
# ____________________________________________________________________________________________________
# input_66 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_26 (LSTM)                   (None, 32)            12416       dropout_61[0][0]
# ____________________________________________________________________________________________________
# dense_87 (Dense)                 (None, 64)            10816       input_66[0][0]
# ____________________________________________________________________________________________________
# dropout_62 (Dropout)             (None, 32)            0           lstm_26[0][0]
# ____________________________________________________________________________________________________
# dropout_63 (Dropout)             (None, 64)            0           dense_87[0][0]
# ____________________________________________________________________________________________________
# dense_86 (Dense)                 (None, 24)            792         dropout_62[0][0]
# ____________________________________________________________________________________________________
# dense_88 (Dense)                 (None, 24)            1560        dropout_63[0][0]
# ____________________________________________________________________________________________________
# add_26 (Add)                     (None, 24)            0           dense_86[0][0]
#                                                                    dense_88[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_67 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_27 (Conv1D)               (None, 7, 64)         1600        input_67[0][0]
# ____________________________________________________________________________________________________
# dropout_64 (Dropout)             (None, 7, 64)         0           conv1d_27[0][0]
# ____________________________________________________________________________________________________
# input_68 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_27 (LSTM)                   (None, 32)            12416       dropout_64[0][0]
# ____________________________________________________________________________________________________
# dense_90 (Dense)                 (None, 64)            10816       input_68[0][0]
# ____________________________________________________________________________________________________
# dropout_65 (Dropout)             (None, 32)            0           lstm_27[0][0]
# ____________________________________________________________________________________________________
# dropout_66 (Dropout)             (None, 64)            0           dense_90[0][0]
# ____________________________________________________________________________________________________
# dense_89 (Dense)                 (None, 24)            792         dropout_65[0][0]
# ____________________________________________________________________________________________________
# dense_91 (Dense)                 (None, 24)            1560        dropout_66[0][0]
# ____________________________________________________________________________________________________
# add_27 (Add)                     (None, 24)            0           dense_89[0][0]
#                                                                    dense_91[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_69 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_28 (Conv1D)               (None, 7, 64)         1600        input_69[0][0]
# ____________________________________________________________________________________________________
# dropout_67 (Dropout)             (None, 7, 64)         0           conv1d_28[0][0]
# ____________________________________________________________________________________________________
# input_70 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_28 (LSTM)                   (None, 32)            12416       dropout_67[0][0]
# ____________________________________________________________________________________________________
# dense_93 (Dense)                 (None, 64)            10816       input_70[0][0]
# ____________________________________________________________________________________________________
# dropout_68 (Dropout)             (None, 32)            0           lstm_28[0][0]
# ____________________________________________________________________________________________________
# dropout_69 (Dropout)             (None, 64)            0           dense_93[0][0]
# ____________________________________________________________________________________________________
# dense_92 (Dense)                 (None, 24)            792         dropout_68[0][0]
# ____________________________________________________________________________________________________
# dense_94 (Dense)                 (None, 24)            1560        dropout_69[0][0]
# ____________________________________________________________________________________________________
# add_28 (Add)                     (None, 24)            0           dense_92[0][0]
#                                                                    dense_94[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_71 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_29 (Conv1D)               (None, 7, 64)         1600        input_71[0][0]
# ____________________________________________________________________________________________________
# dropout_70 (Dropout)             (None, 7, 64)         0           conv1d_29[0][0]
# ____________________________________________________________________________________________________
# input_72 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_29 (LSTM)                   (None, 32)            12416       dropout_70[0][0]
# ____________________________________________________________________________________________________
# dense_96 (Dense)                 (None, 64)            10816       input_72[0][0]
# ____________________________________________________________________________________________________
# dropout_71 (Dropout)             (None, 32)            0           lstm_29[0][0]
# ____________________________________________________________________________________________________
# dropout_72 (Dropout)             (None, 64)            0           dense_96[0][0]
# ____________________________________________________________________________________________________
# dense_95 (Dense)                 (None, 24)            792         dropout_71[0][0]
# ____________________________________________________________________________________________________
# dense_97 (Dense)                 (None, 24)            1560        dropout_72[0][0]
# ____________________________________________________________________________________________________
# add_29 (Add)                     (None, 24)            0           dense_95[0][0]
#                                                                    dense_97[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_73 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_30 (Conv1D)               (None, 7, 64)         1600        input_73[0][0]
# ____________________________________________________________________________________________________
# dropout_73 (Dropout)             (None, 7, 64)         0           conv1d_30[0][0]
# ____________________________________________________________________________________________________
# input_74 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_30 (LSTM)                   (None, 32)            12416       dropout_73[0][0]
# ____________________________________________________________________________________________________
# dense_99 (Dense)                 (None, 64)            10816       input_74[0][0]
# ____________________________________________________________________________________________________
# dropout_74 (Dropout)             (None, 32)            0           lstm_30[0][0]
# ____________________________________________________________________________________________________
# dropout_75 (Dropout)             (None, 64)            0           dense_99[0][0]
# ____________________________________________________________________________________________________
# dense_98 (Dense)                 (None, 24)            792         dropout_74[0][0]
# ____________________________________________________________________________________________________
# dense_100 (Dense)                (None, 24)            1560        dropout_75[0][0]
# ____________________________________________________________________________________________________
# add_30 (Add)                     (None, 24)            0           dense_98[0][0]
#                                                                    dense_100[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_75 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_31 (Conv1D)               (None, 7, 64)         1600        input_75[0][0]
# ____________________________________________________________________________________________________
# dropout_76 (Dropout)             (None, 7, 64)         0           conv1d_31[0][0]
# ____________________________________________________________________________________________________
# input_76 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_31 (LSTM)                   (None, 32)            12416       dropout_76[0][0]
# ____________________________________________________________________________________________________
# dense_102 (Dense)                (None, 64)            10816       input_76[0][0]
# ____________________________________________________________________________________________________
# dropout_77 (Dropout)             (None, 32)            0           lstm_31[0][0]
# ____________________________________________________________________________________________________
# dropout_78 (Dropout)             (None, 64)            0           dense_102[0][0]
# ____________________________________________________________________________________________________
# dense_101 (Dense)                (None, 24)            792         dropout_77[0][0]
# ____________________________________________________________________________________________________
# dense_103 (Dense)                (None, 24)            1560        dropout_78[0][0]
# ____________________________________________________________________________________________________
# add_31 (Add)                     (None, 24)            0           dense_101[0][0]
#                                                                    dense_103[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_77 (InputLayer)            (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_32 (Conv1D)               (None, 7, 64)         1600        input_77[0][0]
# ____________________________________________________________________________________________________
# dropout_79 (Dropout)             (None, 7, 64)         0           conv1d_32[0][0]
# ____________________________________________________________________________________________________
# input_78 (InputLayer)            (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_32 (LSTM)                   (None, 32)            12416       dropout_79[0][0]
# ____________________________________________________________________________________________________
# dense_105 (Dense)                (None, 64)            10816       input_78[0][0]
# ____________________________________________________________________________________________________
# dropout_80 (Dropout)             (None, 32)            0           lstm_32[0][0]
# ____________________________________________________________________________________________________
# dropout_81 (Dropout)             (None, 64)            0           dense_105[0][0]
# ____________________________________________________________________________________________________
# dense_104 (Dense)                (None, 24)            792         dropout_80[0][0]
# ____________________________________________________________________________________________________
# dense_106 (Dense)                (None, 24)            1560        dropout_81[0][0]
# ____________________________________________________________________________________________________
# add_32 (Add)                     (None, 24)            0           dense_104[0][0]
#                                                                    dense_106[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_79 (InputLayer)            (None, 168, 1)        0
# ...
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_591 (InputLayer)           (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_289 (Conv1D)              (None, 7, 64)         1600        input_591[0][0]
# ____________________________________________________________________________________________________
# dropout_850 (Dropout)            (None, 7, 64)         0           conv1d_289[0][0]
# ____________________________________________________________________________________________________
# input_592 (InputLayer)           (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_289 (LSTM)                  (None, 32)            12416       dropout_850[0][0]
# ____________________________________________________________________________________________________
# dense_876 (Dense)                (None, 64)            10816       input_592[0][0]
# ____________________________________________________________________________________________________
# dropout_851 (Dropout)            (None, 32)            0           lstm_289[0][0]
# ____________________________________________________________________________________________________
# dropout_852 (Dropout)            (None, 64)            0           dense_876[0][0]
# ____________________________________________________________________________________________________
# dense_875 (Dense)                (None, 24)            792         dropout_851[0][0]
# ____________________________________________________________________________________________________
# dense_877 (Dense)                (None, 24)            1560        dropout_852[0][0]
# ____________________________________________________________________________________________________
# add_289 (Add)                    (None, 24)            0           dense_875[0][0]
#                                                                    dense_877[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_593 (InputLayer)           (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_290 (Conv1D)              (None, 7, 64)         1600        input_593[0][0]
# ____________________________________________________________________________________________________
# dropout_853 (Dropout)            (None, 7, 64)         0           conv1d_290[0][0]
# ____________________________________________________________________________________________________
# input_594 (InputLayer)           (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_290 (LSTM)                  (None, 32)            12416       dropout_853[0][0]
# ____________________________________________________________________________________________________
# dense_879 (Dense)                (None, 64)            10816       input_594[0][0]
# ____________________________________________________________________________________________________
# dropout_854 (Dropout)            (None, 32)            0           lstm_290[0][0]
# ____________________________________________________________________________________________________
# dropout_855 (Dropout)            (None, 64)            0           dense_879[0][0]
# ____________________________________________________________________________________________________
# dense_878 (Dense)                (None, 24)            792         dropout_854[0][0]
# ____________________________________________________________________________________________________
# dense_880 (Dense)                (None, 24)            1560        dropout_855[0][0]
# ____________________________________________________________________________________________________
# add_290 (Add)                    (None, 24)            0           dense_878[0][0]
#                                                                    dense_880[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_595 (InputLayer)           (None, 168, 1)        0
# ____________________________________________________________________________________________________
# conv1d_291 (Conv1D)              (None, 7, 64)         1600        input_595[0][0]
# ____________________________________________________________________________________________________
# dropout_856 (Dropout)            (None, 7, 64)         0           conv1d_291[0][0]
# ____________________________________________________________________________________________________
# input_596 (InputLayer)           (None, 168)           0
# ____________________________________________________________________________________________________
# lstm_291 (LSTM)                  (None, 32)            12416       dropout_856[0][0]
# ____________________________________________________________________________________________________
# dense_882 (Dense)                (None, 64)            10816       input_596[0][0]
# ____________________________________________________________________________________________________
# dropout_857 (Dropout)            (None, 32)            0           lstm_291[0][0]
# ____________________________________________________________________________________________________
# dropout_858 (Dropout)            (None, 64)            0           dense_882[0][0]
# ____________________________________________________________________________________________________
# dense_881 (Dense)                (None, 24)            792         dropout_857[0][0]
# ____________________________________________________________________________________________________
# dense_883 (Dense)                (None, 24)            1560        dropout_858[0][0]
# ____________________________________________________________________________________________________
# add_291 (Add)                    (None, 24)            0           dense_881[0][0]
#                                                                    dense_883[0][0]
# ====================================================================================================
# Total params: 27,184
# Trainable params: 27,184
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-0c6dfff1cd3d> in <module>()
#      20         x = Conv1D(64, kernel_size=24, strides=24, padding='valid', activation=params['conv_activation'])(conv_input_layer)
#      21         x = Dropout(params['dropout'])(x)
# ---> 22         x = LSTM(32, recurrent_activation=params['recurrent_activation'])(x)
#      23         x = Dropout(params['dropout'])(x)
#      24         x = Dense(24)(x)
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, **kwargs)
#     260         # modify the input spec to include the state.
#     261         if initial_state is None:
# --> 262             return super(Recurrent, self).__call__(inputs, **kwargs)
#     263
#     264         if not isinstance(initial_state, (list, tuple)):
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     594
#     595             # Actually call the layer, collecting output(s), mask(s), and shape(s).
# --> 596             output = self.call(inputs, **kwargs)
#     597             output_mask = self.compute_mask(inputs, previous_mask)
#     598
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state)
#     339                                              constants=constants,
#     340                                              unroll=self.unroll,
# --> 341                                              input_length=input_shape[1])
#     342         if self.stateful:
#     343             updates = []
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length)
#    2457
#    2458         time_steps = tf.shape(inputs)[0]
# -> 2459         outputs, _ = step_function(inputs[0], initial_states + constants)
#    2460         output_ta = tensor_array_ops.TensorArray(
#    2461             dtype=outputs.dtype,
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/keras/layers/recurrent.py in step(self, inputs, states)
#    1160             f = self.recurrent_activation(x_f + K.dot(h_tm1 * rec_dp_mask[1],
#    1161                                                       self.recurrent_kernel_f))
# -> 1162             c = f * c_tm1 + i * self.activation(x_c + K.dot(h_tm1 * rec_dp_mask[2],
#    1163                                                             self.recurrent_kernel_c))
#    1164             o = self.recurrent_activation(x_o + K.dot(h_tm1 * rec_dp_mask[3],
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     819       if not isinstance(y, sparse_tensor.SparseTensor):
#     820         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 821       return func(x, y, name=name)
#     822
#     823   def binary_op_wrapper_sparse(sp_x, y):
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1042   is_tensor_y = isinstance(y, ops.Tensor)
#    1043   if is_tensor_y:
# -> 1044     return gen_math_ops._mul(x, y, name=name)
#    1045   else:
#    1046     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mul(x, y, name)
#    1432     A `Tensor`. Has the same type as `x`.
#    1433   """
# -> 1434   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1435   return result
#    1436
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     766         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     767                          input_types=input_types, attrs=attr_protos,
# --> 768                          op_def=op_def)
#     769         if output_structure:
#     770           outputs = op.outputs
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2336                     original_op=self._default_original_op, op_def=op_def)
#    2337     if compute_shapes:
# -> 2338       set_shapes_for_outputs(ret)
#    2339     self._add_op(ret)
#    2340     self._record_op_seen_by_control_dependencies(ret)
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    1717       shape_func = _call_cpp_shape_fn_and_require_op
#    1718
# -> 1719   shapes = shape_func(op)
#    1720   if shapes is None:
#    1721     raise RuntimeError(
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    1667
#    1668   def call_with_requiring(op):
# -> 1669     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1670
#    1671   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     608     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     609                                   input_tensors_as_shapes_needed,
# --> 610                                   debug_python_shape_fn, require_shape_fn)
#     611     if not isinstance(res, dict):
#     612       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     647     # pylint: enable=protected-access
#     648     return r.SerializeToString()
# --> 649   input_shapes = [tensor_to_inference_result(i) for i in op.inputs]
#     650
#     651   input_tensors = [None for i in input_shapes]
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in <listcomp>(.0)
#     647     # pylint: enable=protected-access
#     648     return r.SerializeToString()
# --> 649   input_shapes = [tensor_to_inference_result(i) for i in op.inputs]
#     650
#     651   input_tensors = [None for i in input_shapes]
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in tensor_to_inference_result(t)
#     640
#     641   def tensor_to_inference_result(t):
# --> 642     r = cpp_shape_inference_pb2.CppShapeInferenceResult()
#     643     r.shape.CopyFrom(t.get_shape().as_proto())
#     644     # pylint: disable=protected-access
#
# ~/opt/anaconda3/envs/datascience/lib/python3.6/site-packages/google/protobuf/internal/python_message.py in init(self, **kwargs)
#     465     return value
#     466
# --> 467   def init(self, **kwargs):
#     468     self._cached_byte_size = 0
#     469     self._cached_byte_size_dirty = len(kwargs) > 0
#
# KeyboardInterrupt:

# %%
f, ax = plt.subplots()
pd.DataFrame(hist.history).plot(figsize=(12, 8), ax=ax)
ax.set_ylim([0, 0.0075])
